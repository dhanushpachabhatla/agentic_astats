# %% [markdown]
# # AStats — Initial Data Exploration
# **Dataset:** `eval5_hierarchical.csv`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 1. Load Dataset

# %%
df = pd.read_csv(r'C:\Users\dhanu\Desktop\Astats preliminary work\sample_data\eval_datasets\eval5_hierarchical.csv')
df.head()

# %% [markdown]
# ## 2. Dataset Info

# %%
df.info()
df.describe(include='all')
